# %%
from scipy.io import loadmat
import os

# %%
data = loadmat(os.path.join('..\Tmaze_Data\\252-1375\\2018-01-07_15-14-54\\04_tmaze1', 'Spike_Data_Binned.mat'))

# %%
data['Spike_Data_Bin'].squeeze().shape
# Out:
# (40,)

# %%
data['Spike_Data_Bin'].squeeze()[0].shape
# Out:
# (319, 40)

# %%
data = data['Spike_Data_Bin'].squeeze()

# %%
import pickle as pkl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %matplotlib widget

# %%
# %matplotlib widget

ax = plt.figure().add_subplot(projection='3d')

#for s in data:
   # ax.plot(s[:, 0], s[:, 1], s[:, 2])

ax.plot(data[0][:, 0], data[0][:, 1], data[0][:, 2])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
