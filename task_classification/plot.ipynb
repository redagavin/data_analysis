# %%
from scipy.io import loadmat
import os

# %%
data_left = loadmat(os.path.join('..\Tmaze_Data\\252-1375\\2018-01-07_15-14-54\\04_tmaze1', 'Spike_Data_Binned_Left.mat'))

# %%
data_left = data_left['Spike_Data_Bin_Left'].squeeze()

# %%
data_right = loadmat(os.path.join('..\Tmaze_Data\\252-1375\\2018-01-07_15-14-54\\04_tmaze1', 'Spike_Data_Binned_Right.mat'))

# %%
data_right = data_right['Spike_Data_Bin_Right'].squeeze()

# %%
import pickle as pkl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %matplotlib widget

# %%
# %matplotlib widget

ax = plt.figure().add_subplot(projection='3d')

#for s in data:
   # ax.plot(s[:, 0], s[:, 1], s[:, 2])

ax.plot(data_left[0][:, 0], data_left[0][:, 1], data_left[0][:, 2], label='left', alpha=0.75)
ax.plot(data_right[0][:, 0], data_right[0][:, 1], data_right[0][:, 2], label='right', alpha=0.75)
ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
